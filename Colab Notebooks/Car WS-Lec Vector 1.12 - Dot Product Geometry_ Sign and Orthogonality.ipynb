# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# # **$$ ⛳ \textbf{  Dot Product Geometry: Sign and Orthogonality }⛳ $$**

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **Objectives**
#
# By the end of this lesson, you will:
#
# #### - Understand the geometric interpretation of the dot product.
# #### - Know how to compute the angle between any two vectors
# #### - Obserbe the equivalence of the algebraic and geometric perspectives on the dot product.

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **The Geometric Perspective of a Dot Product**
#
# <details>
#   <summary><b>Show Explanation</b></summary>
#
# <p style="text-align:center;"><img src = "https://drive.google.com/uc?id=1891DPyKFmmV8-g0oqOtComt0-D1iBmUx" width = "1400px" height = "500px" />
# The DOT product here $ \langle \mathbf{a},  \mathbf{b}\rangle\,$ is the length of **a** times, the length of **b** times, the cosine of the angle between the two vectors.
#
# By the way, you can see that **single vertical lines** $|\mathbf{a}|$ used to indicate the length of a vector instead of  double vertical lines $\left\Vert  \mathbf{a } \right\Vert$
# </details>

# %% [markdown]
# ####**Not everyone** uses the same notation conventions all the time. so it's important for you to learn to be a little bit **flexible** and to see the math and the concepts, even if the notations are slightly different.

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **Compute the angele between a Two Vectors Using Dot product**
#
# <details>
#   <summary><b>Show illustration on how to compute the angle</b></summary>
#
# <p style="text-align:center;"><img src = "https://drive.google.com/uc?id=1hbCrm0fVirPwqtK1M8JFxP2hLMmb_ZQ7" width = "1400px" height = "500px" />
# So first, we divide both sides of the equation by the length of a times, the length of **b**.  And now we have the cosine of theta on one side.
#
# Now we need to invert the cosine or apply the inverse cosine to both sides of the equation that will cancel out the cosine on the right hand side.
#
# So that gives us that the theta the **angle between two vectors** is the inverse cosine or it's sometimes called the arc cosine of the DOT product between the two vectors divided by or scaled by the product of the lengths.
# </details>

# %% [markdown]
# #### And it's interesting that this formula is derived from the two dimentions, but it actually works for **any dimensionality**, not just for the easily visualizable dimensions.

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **Sign and Orthogonality of Dot Product of Two Vectors Based on the Angle Between Them**
#
# <details>
#   <summary><b>Show Dot Product Features</b></summary>
#
# <p style="text-align:center;"><img src = "https://drive.google.com/uc?id=1AKdnE-n827yMlUDnvtVuabjyxLhdV0Z0" width = "1400px" height = "500px" />
#
# * The **cosine** of an angle is bound between minus one and plus one $-1\le \theta \le 1$.
#
# * The **lengths of vectors** also are strictly non-negative numbers $|\mathbf{a}| \ge 0$
#
# * The combination of the range of $\theta$ with the non-negative lengths of vectors gives us some interesting insights into the DOT product and how the sign of the DOT product is related to the relationship between the two vectors.
#
# That's because when you look at the formula $$ \langle \mathbf{a, b} \rangle= |\mathbf{a}| |\mathbf{b}|\text{cos}( \theta_{ab} $$ here, you see that the two factors $|\mathbf{a}|$ and  $|\mathbf{b}|$ are always going to be **non-negative.**
#
# * Unless one of the is zero vector or $|\mathbf{a}|$ and  $|\mathbf{b}|$ will be positive.  So the the only factor in this term that can possibly be negative is the **cosine** of the angle between the two vectors.
#
# * If the cosine of the angle between the two vectors is less than $90^∘$ degrees or $\pi/2$ then you would say that the two vectors meet at an acute angle.
#
#   And the cosine of that angle is necessarily going to be positive because the cosine of an acute angle is positive. So that means that the DOT product must be positive.
#
# * If you see a DOT product between two vectors that is greater than zero, then that indicates that those two vectors have an angle between them of less than $90^∘$.
#
# * If the angle is obtuse or if it's greater than $90^∘$ degrees, then the cosine will be negative. And that means that the DOT product will also be negative.
#
# * If the angle between the two vectors is exactly $90^∘$ degrees or $\pi/2$ making this a right triangle outside a right angle. Then the DOT product is zero.
#
#   And that's because the cosine of 90 degrees of the cos$(\pi/2) = 0$.  So looking back at this term, you have zero times something time something. So it doesn't actually matter how **long** or how **short** these two vectors are.
#
# * If they meet at a right angle, then the DOT product between these two vectors is necessarily going to be zero.
#
#   This is such an important case that is given its own special name of orthogonal. And **orthogonal** is an important word, it's an important concept that will come up very often in linear algebra.
#
# * When the two vectors are pointed in the opposite direction ($\theta$ is 180 degrees or $\pi$ radians).
#
#   Then vector **b**, for example, would be pointing exactly this other direction as vector **a**, as if you would multiply this vector by a scalar minus one.
#
#   In that case, the cosine of 180 degrees or $\pi$ is minus one.  So then the DOT product would be basically the same thing.  But with a negative sign in front of it.
#
# * Finally when the vectors point in exactly the same direction, then the angle between them is zero.  So in this case, the angle between the two vectors is zero and the cosine of zero is one.
#
#   So that means in this case, the DOT product actually reduces to the multiplication of the length of the two vectors.
#
# * So **b** is equal to **a**, then the dot product of the vector with itself is simply its length times its length.
#
#   And that's the length squared, of course and the square root of that is the length that provides an additional geometric explanation for why the length of a vector is computed as the square root of the dot product of the vector with itself.
# </details>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **Proof of equality of dot prodoct between algerabic Definition and Geometric Representations**

# %% [markdown]
# $$\Large \textbf{Dot Product }\, = \langle \color{blue}{\mathbf{a}}\, , \, \color{green}{\mathbf{b}}\rangle\,=\,\color{blue}{\mathbf{a}}^{\text{T}}\color{green}{\mathbf{b}}\,= \,\underbrace{\sum_{i=1}^n\color{blue}{\mathbf{a}}_i\color{green}{\mathbf{b}}_i }_{\color{orange}{\textbf{Algebra}}}\,=\,\underbrace{\text{cos}( \theta_{\color{blue}{\mathbf{a}}\color{green}{\mathbf{b}}} ) \left\Vert \color{blue}{\mathbf{a}}\left\Vert \right\Vert\color{green}{\mathbf{b}}\right\Vert}_{\color{pink}{\textbf{Geometry}}}$$

# %% [markdown]
# <details>
#   <summary><b>Show Proof of Equivalency of Algebraic and Geometric Dot product</b></summary>
#
# <p style="text-align:center;"><img src = "https://drive.google.com/uc?id=1X39gHd5owfG2rd6JbyZFvCV726-KblvG" width = "1400px" height = "500px" />
# </details>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **Python for visualization of dot product**

# %% [markdown]
# ### **🔖 $\color{blue}{\textbf{Practice: }}$ Compute the numerical value of the angle using Python**

# %%
import numpy as np
import math

v1 = np.array([2, 4, -3]) #numpy does not specify is a vector is a row or col
v2 = np.array([0, -3, -3])

# compute the radian between v1 and v2

ang = np.arccos(np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2)))

print(f"the angle between {v1} and {v2} is {ang: .1f} in radian and {ang/np.pi * 180: .2f} in degrees")
# Out:
# the angle between [ 2  4 -3] and [ 0 -3 -3] is  1.7 in radian and  97.55 in degrees

# %% [markdown]
# ---
#
# ## **Visualization of vectors and the angle between them**

# %%
#@title Visualization of Vectors { run: "auto", vertical-output: true }
#@markdown Enter the three coordinate x1, y1, z1 of the vector v1
x1 = -3 #@param {type:"number"}
y1 = 4 #@param {type:"number"}
z1 = -3 #@param {type:"number"}

#@markdown Enter the three coordinate x2, y2, z2 of the vector v2
x2 = 0 #@param {type:"number"}
y2 = 2 #@param {type:"number"}
z2 = -3 #@param {type:"number"}

import numpy as np
import plotly.graph_objects as go

# two vectors
v1 = np.array([ x1,  y1, z1 ])
v2 = np.array([ x2,  y2, z2 ])

# compute the angle (radians) between two vectors
ang = np.arccos( np.dot(v1,v2) / (np.linalg.norm(v1)*np.linalg.norm(v2)) ) 


#axis_lim = abs(max(abs(Vs))
#lim_min = min(np.array([x1, y1, z1]))
#lim_max = max([x1, y1, z1])
axis = dict(showgrid=True, zeroline=True, zerolinecolor = "black", showticklabels=True, 
            #nticks = 1,
                       #range = [min(min(Vs), min(Vir)) - 1, max(max(Vs), max(Vir)) + 1])
                       #range = [lim_min-1, lim_max+1]
            )

fig = go.Figure()

# plot v1
fig.add_trace(go.Scatter3d(x=[0, v1[0]], y=[0, v1[1]], z = [0, v1[2]], 
                         mode = "lines", line = dict(color = 'green', width= 6),
                         ))

fig.add_trace(
              go.Cone(
                      x=[v1[0]],
                      y=[v1[1]],
                      z=[v1[2]],
                      u=[v1[0]],
                      v=[v1[1]],
                      w=[v1[2]],
                    sizemode="absolute",
                    sizeref=0.5,
                    anchor="tip",
                    colorscale='greens',
                    showscale=False,
    ))

#plot v2
fig.add_trace(go.Scatter3d(x=[0, v2[0]], y=[0, v2[1]], z = [0, v2[2]], 
                         mode = "lines", line = dict(color = 'blue', width= 6),
                         ))

fig.add_trace(
              go.Cone(
                      x=[v2[0]],
                      y=[v2[1]],
                      z=[v2[2]],
                      u=[v2[0]],
                      v=[v2[1]],
                      w=[v2[2]],
                    sizemode="absolute",
                    sizeref=0.5,
                    anchor="tip",
                    colorscale='blues',
                    showscale=False,
    ))

fig.update_layout( width = 800,
                title = f'Angle between vectors: {(ang/np.pi * 180): .1f} degrees',
                title_x = 0.5,
                margin=dict(r=0, l=0, b=0, t=30),
                scene_aspectmode='cube',
                scene = dict(
                              #xaxis = dict(showgrid=False, zeroline=False, zerolinecolor = "black", nticks=4, range=[-1,4],),
                              #yaxis = dict(showgrid=False, zeroline=False, zerolinecolor = "black", nticks=4, 
                                           #range=[-1,4],),
                              #zaxis = dict(nticks=4, range=[-1,4],),
                              xaxis = axis,
                              yaxis = axis,
                              zaxis = axis,
                              annotations=[
                                          dict(
                                              showarrow=False,
                                              x= v1[0],
                                              y= v1[1],
                                              z= v1[2],
                                              text=f"[{v1[0]}, {v1[1]}, {v1[2]}]",
                                              xanchor="left",
                                              xshift=10,
                                              opacity=1
                                              ),
                                           dict(
                                              showarrow=False,
                                              x= v2[0],
                                              y= v2[1],
                                              z= v2[2],
                                              text=f"[{v2[0]}, {v2[1]}, {v2[2]}]",
                                              xanchor="left",
                                              xshift=10,
                                              opacity=1
                                              ),
                                          ]
                              ),
                showlegend = False,
                font=dict(
                color="black",
                size=14
            ),
)
# hiding color-bar
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ---
#
# ## **🔖 $\color{blue}{\textbf{Practice: }}$Experical Proof of Algebraic and Geometric Formulas of Dot Product**

# %%
# prove equvilancy of algebraic and geometric dot product formulas

import numpy as np
import math

v1 = np.array([2, 4, -3]) #numpy does not specify is a vector is a row or col
v2 = np.array([0, -3, -3])

# compute the radian between v1 and v2

# dot product algebraic way
dp_a = np.dot(v1, v2)

# Geometric way
ang = np.arccos(np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2)))

# dot product
dp_g = np.linalg.norm(v1) * np.linalg.norm(v2) * np.cos(ang)

print(f"the angle between {v1} and {v2} is {ang: .1f} in radian and {ang/np.pi * 180: .2f} in degrees")
print(f"dot product using algebra = {dp_a}")
print(f"dot product using geometry = {dp_g}")
# Out:
# the angle between [ 2  4 -3] and [ 0 -3 -3] is  1.7 in radian and  97.55 in degrees
# dot product using algebra = -3
# dot product using geometry = -3.0000000000000013

# %% [markdown]
# #### 🌼 We notice that there is a **tiny difference** of the dot product due to the computer precision error
