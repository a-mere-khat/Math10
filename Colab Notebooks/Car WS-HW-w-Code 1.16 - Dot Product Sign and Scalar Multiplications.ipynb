# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# # **$$ ⛳ \textbf{   Sign of a Dot Product Sign and Scalar Multiplications  }⛳ $$**

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **Objective:**

# %% [markdown]
# #### Determine whether the sign of the DOT product is invariant to scalar multiplication versus whether the sign of the DOT product is affected by scalar multiplication.
#
#
# #### ⛽ There are many resources for writing text in markdown and mathematics typesets in latex.  Here is one for matrix
# [How to write matrices in Latex ?](https://www.math-linux.com/latex-26/faq/latex-faq/article/how-to-write-matrices-in-latex-matrix-pmatrix-bmatrix-vmatrix-vmatrix)
#
# [Markdown Cheatsheet.]( https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet)
#
# 🚥 But keep in mind that these numerical demonstrations in a couple of examples are not formal mathematical proofs, and these are not substitutes for formal mathematical proofs. These are just really great ways to help you internalize the concepts.

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **🔖  TODOs**

# %% [markdown]
# ---
# ### **$\color{brown}{\textbf{TODO 1: }}$ State Your hypothesis**

# %% [markdown]
# ---
# ### **$\color{brown}{\textbf{TODO 2: }}$ Recommendated Steps for code the experiment**
#
# ##### ✅ **$\color{darkorange}{\textbf{There are many different versions of solutions}}$**

# %% [markdown]
# #### **1.** Generate **two integer vectors in $R^3$.**
# #### **2.** Generate two scalars and printout the scalars.
# #### **3.** Compute the dot product between the vectors.
# #### **4.** Compute the dot product between the scaledvectors by the two scalars of your choice in **2.**
# #### **5.** Add print statements with identification in the appropriate places.

# %%
#Your code goes here

# %% [markdown]
# ---
#
# ### **$\color{brown}{\textbf{TODO 3: }}$ Running experiments and testing out different hypotheses, exploring these vectors and this concept of dot product and scalar multiplication.**
#
# #### **Step 1:** Identify possible combinations of cases for the vectors and scalars.
#
# #### **Step 2:** Run your code with the data for each case.
#
# #### **Step 3:** In a text cell, documents the vectors and scalars you used in each case and write a discussion the outputs from algebraic and geometric perspectives.
#
# ##### ✅ **$\color{darkorange}{\textbf{There are many different versions of solutions}}$**

# %% [markdown]
# For example:
#
# **Case 1: dot product is zero**
#   $\mathbf{u} = [-3, 4, 5], \mathbf{v} = [3, 6, -3], \text{s1} = 2$, and $\text{s2} = 3$
#
# * Dot products: $\mathbf{u}\cdot \mathbf{v} = 0$ and $(\text{s1}\mathbf{u})\cdot (\text{s2}\mathbf{v}) = 0$
#
# Discussion:
#
# 1.  Algebraical conclusion: If the dot product of two vectors are zero, the dot product of the scaled vectors will also be zero no matter what scalars we choose because multiplication of multiplicative property of zero: zero multiply any finite number will remain to be zero.
#
# 2. Geometric Interpretation: $\mathbf{u}$ and $\mathbf{v} $ are orthogonal to each other and meet at a right angle.  Multiplication of $\mathbf{u}$ and $\mathbf{v} $ by a scalars, both of these vectors becomes longer or shorter.  But they're still meeting at a right angle and the cosine between these two vectors is still 90 degrees

# %% [markdown]
# **Case 2: s1 and s2 both positive**
#
#  $\mathbf{u} = [-3, 4, 6], \mathbf{v} = [3, 6, -3], \text{s1} = 2$, and $\text{s2} = 3$
#
#
# * Dot products: $\mathbf{u}\cdot \mathbf{v} = -3$ and $(\text{s1}\mathbf{u})\cdot (\text{s2}\mathbf{v}) = 6 \cdot (-3) = -18$
#
# Discussion:
#
# 1.  Algebraical conclusion: We are taking the dot product of $\mathbf{u}$ and $\mathbf{v} $, which is a single number and scaled it by the product of the two scalars s1 $\cdot$s2 = 6. So the dot product of two scaled factor is -18.
#
# 2. Geometric Interpretation: since the dot product of $\mathbf{u}$ and $\mathbf{v} $ are negative, meaning tht they are at an obtuse angle (greater than 90 degree and less than 180 degree.  Since s1$\cdot$s2$>0$ the scaled dot product is positive. The two vectors remins at an obtuse angle after scaling.
#
# **Case 3:**
#  $\mathbf{u} = [-3, 4, 6], \mathbf{v} = [3, 6, -3], \text{s1} = -2$, and $\text{s2} = 3$
#
#
# * Dot products: $\mathbf{u}\cdot \mathbf{v} = -3$ and $(\text{s1}\mathbf{u})\cdot (\text{s2}\mathbf{v}) = (-6) \cdot (-3)=18$
#
#
# Discussion:
#
# 1.  Algebraical conclusion: We are taking the dot product of $\mathbf{u}$ and $\mathbf{v} $, which is a single number and scaled it by the product of the two scalars s1 $\cdot$s2 = -6. So the dot product of two scaled factor is 18.
#
# 2. Geometric Interpretation: since the dot product of $\mathbf{u}$ and $\mathbf{v} $ are negative, meaning tht they are at an obtuse angle (greater than 90 degree and less than 180 degree.  The 2 in s1$\mathbf{u}$ double the length of the vector $\mathbf{u}$ and the negative sign flips the direction of $\mathbf{u}$.  $\mathbf{u}$ and $\mathbf{v}$ now meet at an acute angle, that is less than 90 degrees.
#
# **Case 4:** $\text{s1} = 0$, and $\text{s2} = 3$
#
# **Case 5:** $\text{s1} = 1$, and $\text{s2} = 1$
#
# **Case 6:** What happens when you have different dimensionality or these vectors are in two dimensions or 10 dimensions?

# %% [markdown]
# ---
# ### **$\color{brown}{\textbf{TODO 4: }}$ Write a conlusion based on your experiment**
