# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# # **$$ ⛳ \textbf{  Vector Length (Magnitude or Norm): }⛳ $$**

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **Objectives**
#
# By the end of this lesson, you will:
#
# #### - Know how to compute the length, magnitude, or norm of a vector
# #### - understand the connection between 2d vector components and the geometric features of Pythagorean theorem

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **Vector Length: Algebra**
#
# $$\Large\left\Vert  \mathbf{v} \right\Vert \, =\, \sqrt{\mathbf{v}^{\text{T}}\mathbf{v}}\, = \, \sqrt{\sum_i^n\mathbf{v}_i\mathbf{v}_i}$$
# ####where **v** is a vector.

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **Vector Length: Geometry**
#
# Given $\Large $
# $$\Large\left\Vert  \mathbf{v} \right\Vert = \sqrt{\mathbf{v}^{\text{T}}\mathbf{v}}$$
# ###where **v** is a vector.

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **2d Vector Length and Pythogorean Theorem**
#
# $$\Large \text{Given a vector }\mathbf{v} = \color{blue}{\begin{bmatrix}
#     \mathbf{v}_1 \\
#     \mathbf{v}_2
# \end{bmatrix}} \quad \text{norm: }\left\Vert  \mathbf{v} \right\Vert = \sqrt{\color{blue}{\mathbf{v}_1}^2+\color{blue}{\mathbf{v}_2}^2}$$

# %% [markdown]
# ---
#
# <details>
#   <summary><b>Show Example</b></summary>
#
# <p style="text-align:center;"><img src = "https://drive.google.com/uc?id=1JTsfOh7nWjq2oo-zdj7bET0mASyr7iH1" width = "1100px" height = "500px" />
# </details>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **Vector Length: Computer Code**

# %% [markdown]
# #### **Method 1: Take the square root of the dot product**.

# %% [markdown]
# ⏰ Recall the **five methods** we learned for computing dot product oftwo vectors of $\mathbf{v1}$ and $\mathbf{v2}$ with the same dimensions in Lec Vector 1.4.

# %% [markdown]
# ### **🔖 $\color{blue}{\textbf{Practice: }}$ Write the five methods for computing dot product we leared.  You can use copy paste but format the text as code.**. The example of the element-wise are done for you!

# %% [markdown]
# ---
# ### **Element-wise**
#
# ##### in Native Python
# ```
# dotProduct1 = 0
# for i in range(len(v1)): # loop through the length of the vectors
#   # indentation is for the for-loop
#   dotProduct1 += v1[i] * v2[i]
# ```

# %% [markdown]
# ---
# ### **Element-wise**
#
# ##### numpy.multiply() code to translate the mathematical definition of a dot product of vectors v1 and v2.
# ```
# import numpy as np
# dot_product = 0
# for i in range(len(v1)): # loop through the length of the vectors
#     # this indentation is for the for loop
#     # dot_product += v1[i] * v2[i] # can never skip a multiplication in any programming language
#     dot_product += np.multiply(v1[i], v2[i])
#
#
# ```

# %% [markdown]
# ---
# ### **Vector-wise**
#
# ##### Using numpy library numpy.multiply() code to translate the mathematical definition of a dot product of vectors v1 and v2.
# ```
# import numpy as np
# dot_product = sum(np.multiply(v1, v2))
#
# ```

# %% [markdown]
# ---
# ### **Vector-wise**
#
# ##### Using numpy library numpy.dot() code to translate the mathematical definition of a dot product of vectors v1 and v2.
# ```
# import numpy as np
# dot_product = np.matmul(v1, v2)
#
# ```

# %% [markdown]
# ---
# ### **Vector-wise**
#
# ##### Using numpy library numpy.matmul() code to translate the mathematical definition of a dot product of vectors v1 and v2.
# ```
# import numpy as np
# dot_product = np.dot(v1, v2)
#
# ```

# %% [markdown]
# ### 🪂 **You try to do it follow the above example**

# %%
import numpy as np
dot_product = 0
for i in range(len(v1)): # loop through the length of the vectors
    # this indentation is for the for loop
    dot_product += v1[i] * v2[i] # can never skip a multiplication in any programming language

# %% [markdown]
# ---
# ### **Vector form**

# %% [markdown]
# ### **🔖 $\color{blue}{\textbf{Practice: }}$** Use the code example above to compute the length (norm or magnitude) of the vector below
#
# ### 🪂 **You try it first**

# %%
import numpy as np

# create 2 vectors as list
v1 = [6, 5, 0.2, 321, 0.1, 3.2, 8]
# v2 = [0, 6, 4, 6, 5]

# 1. copy the code from the above method 1 to 5
# 2. calculate the square root of the result, np.sqrt(a), a ** (1/2), a ** (0.5)
# save the norm for each method in v_len_1 ... to v_len_5

# Method 1
dot_product_1 = 0
for i in range(len(v1)):
    dot_product_1 += v1[i] * v1[i]

# method 2
dot_product_2 = 0
for i in range(len(v1)):
    dot_product_2 += np.multiply(v1[i], v1[i])

# method 3
dot_product_3 = sum(np.multiply(v1, v1))

# method 4
dot_product_4 = np.matmul(v1, v1)

# method 5
dot_product_5 = np.dot(v1, v1)

v_len_1 = np.sqrt(dot_product_1)
v_len_2 = np.sqrt(dot_product_2)
v_len_3 = np.sqrt(dot_product_3)
v_len_4 = np.sqrt(dot_product_4)
v_len_5 = np.sqrt(dot_product_5)

print(f"dot_product_1: {dot_product_1}, v_len_1: {v_len_1}\n")
print(f"dot_product_2: {dot_product_2}, v_len_2: {v_len_2}\n")
print(f"dot_product_3: {dot_product_3}, v_len_3: {v_len_3}\n")
print(f"dot_product_4: {dot_product_4}, v_len_4: {v_len_4}\n")
print(f"dot_product_5: {dot_product_5}, v_len_5: {v_len_5}\n")
# Out:
# dot_product_1: 103176.29, v_len_1: 321.21066296124104
#
# dot_product_2: 103176.29, v_len_2: 321.21066296124104
#
# dot_product_3: 103176.29, v_len_3: 321.21066296124104
#
# dot_product_4: 103176.29, v_len_4: 321.21066296124104
#
# dot_product_5: 103176.29, v_len_5: 321.21066296124104

# %% [markdown]
# #### **Method 2: Using  `numpy.linalg` library**

# %%
import numpy as np

v1 = [6, 5, 0.2, 321, 0.1, 3.2, 8]

#norm
v_len_6 = np.linalg.norm(v1)
print(f"using np.linalg.norm(): {v_len_6}")
# Out:
# using np.linalg.norm(): 321.21066296124104
