# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# # **$$ ⛳ \textbf{   Chauchy Shwartz Inequality  }⛳ $$**
#
# The **Cauchy–Schwarz inequality** (also called **Cauchy–Bunyakovsky–Schwarz inequality**) is considered one of the most important and widely used inequalities in mathematics.

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## 🤔 **Objective:**

# %% [markdown]
# #### Upon completing this challenge, you will
# * the fomrula and proof for the Cauchy Shwartz Inequality.
# * Demonstrate the (in)equality in code!
#
# #### ⛽ There are many resources for writing text in markdown and mathematics typesets in latex.  Here is one for matrix
# [How to write matrices in Latex ?](https://www.math-linux.com/latex-26/faq/latex-faq/article/how-to-write-matrices-in-latex-matrix-pmatrix-bmatrix-vmatrix-vmatrix)
#
# [Markdown Cheatsheet.]( https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet)
#
# 🚥 But keep in mind that these numerical demonstrations in a couple of examples are not proofs. These are not formal mathematical proofs, and these are not substitutes for formal mathematical proofs. These are just really great ways to help you internalize the concepts.

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ##🔖  **TODOs**

# %% [markdown]
# ---
# ### **$\color{brown}{\textbf{TODO 1: }}$ State the Inequality**

# %% [markdown]
# The Cauchy–Schwarz inequality states that for all vectors $\mathbf{u}$ and $\mathbf{v}$ of an inner (dot in $R^2$ or $R^3$ product space
#
#
# $$ | \mathbf{u}^T \mathbf{v} | \leq || \mathbf{u} ||\, ||\mathbf{v} || \, \textbf{(Cauchy-Schwarz inequality [written using only the inner product])}$$
#
# where $\mathbf{u}^T \mathbf{v}  $  is the inner product. The two bars $| \, |$ of vertical lines here indicates the absolute value.  Because the DOT product is just one number. So we just need the absolute value.
#
# And here the double vertical lines $||\, \, ||$ refer to the vector magnitude or the length of these two vectors $\mathbf{u}$ and $ \mathbf{v}$.
#
# So the Couchy Schwartz inequality says that the absolute value or the magnitude of the DOT product between two vectors $\mathbf{u}$ and $ \mathbf{v}$ is less than or equal to the product of the norms of those two vectors
#
# Examples of inner products include the real and complex dot product; see the examples in inner product. Every inner product gives rise to a *norm*, called the canonical or *induced norm*, where the norm of a vector $ \mathbf{u} $  is denoted and defined by:
#
#
# $$ \|\mathbf {u} \|:={\sqrt {\mathbf{u}^T \mathbf{u} }}$$
#
#
# so that this norm and the inner product are related by the defining condition $\|\mathbf {u} \|^{2}=|\mathbf{u}^T \mathbf{u}| ,$ where $|\mathbf{u}^T \mathbf{u} |$ is always a non-negative real number (even if the inner product is complex-valued). By taking the square root of both sides of the above inequality, the Cauchy–Schwarz inequality can be written in its more familiar form:
#
# $$ |\mathbf{u}^T \mathbf{v} |\leq \|\mathbf {u} \|\|\mathbf {v} \|.\, \textbf{(Cauchy-Schwarz inequality [written using only the inner product])}$$
#
#
# Moreover, $\color{red}{\text{the two sides are equal if and only if $ \mathbf {u} $ and $ \mathbf {v} $ are linearly dependent}}$.

# %% [markdown]
# ---
# ### **$\color{brown}{\textbf{TODO 2: }}$ Theoretical Proof**
#
# #### There's quite a few proofs for this inequality.  In principle, you can come up with any proof you like the proof that comes from the definition of the DOT product that we recently learebd on the geometric interpretation of the DOT product in $R^2$ and $R^3$.
#
# #### If you have a different proof, then it's also totally fine.

# %% [markdown]
# ---
# ### 🟨 **Proof**
#
# I think the Cauchy Schwartz inequality is really easy to prove when using the geometric definition of the DOT product.
#
# So all I'm going to do here is replace this DOT product here and transpose b with the geometric expression
#
# of that DOT product and that looks like this.
#
# So we have the magnitude of $\mathbf{u}$ times, the magnitude of $\mathbf{v}$ and then times the cosine of the angle between $\mathbf{u}$ and $\mathbf{v}$.
#
# $$ | \mathbf{u}^T \mathbf{v} |  =  || \mathbf{u} ||\, ||\mathbf{v} || \cdot |cos(\theta_{\mathbf{uv}})|$$
#
# Now we also have to account for the absolute value sign here.
#
# In principle, you know, this absolute value signs should really be all the way out here.
#
# The magnitude of these vectors $\mathbf{u}$ and $\mathbf{v}$ are strictly non-negative quantities.
#
# The only term of these three, the only term that can possibly be negative is the cosine.
#
# So therefore, I'm just, you know, for simplicity, moving the absolute value symbol here.
#
# OK, so now this is basically the end of the proof.
#
# We just have to think about this term a little bit.
#
# Keep in mind that this term here, the cosine of any angle is bound between minus one and plus one.
#
# And so therefore the absolute value of the cosine of any angle is bound between zero and one.
#
# $$0\le |cos(\theta_{\mathbf{uv}}) |\le 1$$
#
# So this term cannot be greater than one.
#
# It cannot be less than zero.
#
# So then, you know, you could imagine going even a little bit more than this.
#
# You could divide both sides of the equation by the magnitude of A and the magnitude of B, and you're
#
# going to be left with one over here.
#
# So now the cosine of any angle or the absolute value of the cosine of any angle is necessarily less than or equal to one.
#
# $$ | \mathbf{u}^T \mathbf{v} |  =  || \mathbf{u} ||\, ||\mathbf{v} || \cdot |cos(\theta_{\mathbf{uv}})|\le || \mathbf{u} ||\, ||\mathbf{v} ||$$
#
# And that concludes the proof that proves the Cauhy Shwartz inequality.
#
# OK, so that was step one of this code challenge.

# %% [markdown]
# ---
# ### **$\color{brown}{\textbf{TODO 3: }}$ Code for Experiment of Conditions of Equality vs. Inequality**
#
# Determine the conditions to use equality or inequality signs in Chauchy Shwartz Inequality with support to your statements in Mathematical logics.
#
#
# #### **Step 1:** Create three vectors with dimention > $R^5$: two are independent of each other and the third is linear dependent on one of the previous two vectors.  (Think about what type of vectors are independent and what makes it dependent.)
#
# #### 🎨 $\color{darkorange}{\text{ TIP 1: Two vectors with random numbers from Guassian distributions are astoshingly unlikely to be dependent on each other.}}$
# #### 🎨 $\color{darkorange}{\text{ TIP: 2. Two vectors are linear dependent when their ratio is a none-zero number.}}$
#
# #### **Step 2:** Compute the dot product between the two independent and two dependent vectors
#
# #### **Step 3:** Compute the normal of all vectors and the products and their
#
# #### **Step 4:** print out the results above or differences from step 2 and 3 for the left and right sides of Cauchy Schwards Inequality.

# %%
import numpy as np
#create three vectors two are independent and one is dependent of the other two

a = np.random.randn(5)
b = np.random.randn(5)
c = np.random.randn(1) * a

#print(a)
#print(c)

# compute their dot products

dot_ab = np.dot(a, b)
dot_ac = np.dot(a, c)

# compute the magnitude of dot product and product of normal of vectors
mg_dot_ab = np.abs(dot_ab)
mg_dot_ac = np.abs(dot_ac)
norm_ab = np.linalg.norm(a) * np.linalg.norm(b)
norm_ac = np.linalg.norm(a) * np.linalg.norm(c)
print(f"abs(a, b) vs.  norm(a)*norm(b)\n {mg_dot_ab: .4f}      {norm_ab: .4f}" )
print(f"abs(a, c) vs.  norm(a)*norm(c)\n {mg_dot_ac: .4f}      {norm_ac: .4f}" )
# Out:
# abs(a, b) vs.  norm(a)*norm(b)
#   1.4776       5.4450
# abs(a, c) vs.  norm(a)*norm(c)
#   1.8884       1.8884

# %% [markdown]
# ---
# ### **$\color{brown}{\textbf{TODO 4: }}$ Experiment with your code and documents the results for equality and inequality**

# %% [markdown]
# #### Running the code, we see that
# * the inequality sign applies to the vectors $\mathbf{a}$ and $\mathbf{b}$ where $\mathbf{a}$ and $\mathbf{b} $ are independent of each other.
# * The equality applies to the vectors of $\mathbf{a}$ and $\mathbf{c}$, where $\mathbf{c}$ is linear dependent of $\mathbf{a}$, that is, $\mathbf{a} = \text{constant} \cdot \mathbf{a}$

# %% [markdown]
# ---
# ### **$\color{brown}{\textbf{TODO 5: }}$ Write a conclusion of the conditions for equality and inequality in terms of dependence and independence of the two vectors in the Cauchy Schartz Inequality**

# %% [markdown]
# #### **Case 1:**
#
# $$ | \mathbf{u}^T \mathbf{v} | < || \mathbf{u} ||\, ||\mathbf{v} ||$$  The left hand side of this equation is going to be smaller than the right hand side.
#
# Whenever the angle between $\mathbf{a}$ and $\mathbf{b}$  is anything other than zero and one hundred and eighty degrees Or you could also say zero and $\pi$ radians.
#
# There's another way we can express that so we can express that by saying that if Vector's $\mathbf{a}$ and $\mathbf{ab}$  form a linearly independent set, then this expression becomes an inequality.
#
# This is going to be smaller than the right hand side of the equation.
#
# #### **Case 2:**
# $$ | \mathbf{u}^T \mathbf{v} | = || \mathbf{u} ||\, ||\mathbf{v} ||$$ And if the angle between $\mathbf{a}$ and $\mathbf{b}$  is exactly zero, or if that angle is exactly 180 degrees or $\pi$ radians, then these two sides of the equation are equal.
#
# And that's because the cosine is then equal to minus one or plus one.
#
# And then of course the absolute value is going to make it one.
#
#
# And if A and B form A dependent set, which means that one vector is a scaled version of the other vector, then we have an equality.
