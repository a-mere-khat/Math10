# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# # **$$ ⛳ \textbf{ Is DOT Product Commutative? }⛳ $$**
# #$$A^T \cdot B \stackrel{?}{=} B^T  \cdot A$$

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **Objective:**

# %% [markdown]
# #### Use Python as a tool to help you discover some properties of linear algebra in particular the answer to the question "Is the DOT product commutative?"
#
#
# #### ⛽ There are many resources for writing text in markdown and mathematics typesets in latex.  Here is one for matrix
# [How to write matrices in Latex ?](https://www.math-linux.com/latex-26/faq/latex-faq/article/how-to-write-matrices-in-latex-matrix-pmatrix-bmatrix-vmatrix-vmatrix)
#
# [Markdown Cheatsheet.]( https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet)
#
# 🚥 But keep in mind that these numerical demonstrations in a couple of examples are not formal mathematical proofs, and these are not substitutes for formal mathematical proofs. These are just really great ways to help you internalize the concepts.

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ##🔖  **TODOs**

# %% [markdown]
# ---
# ### **$\color{brown}{\textbf{TODO 1: }}$ State your hypothesis**
#
# That the DOT product is commutative means that a transpose times B is the same thing as B transpose times.
# $$A^T \cdot B = B^T  \cdot A$$

# %% [markdown]
# ---
# ### **$\color{brown}{\textbf{TODO 2: }}$ Code your experiment with integers in two dimentions ($R^2$)**
#
# #### **Step 1:** Generate two 2-elements random integer row vectors $A$ and $B$ and print $A$ and $B$ using `numpy.random.randint(low, high, size)` where `low` and `high` are integers, and `size` is a positive integer.  Initialize two variables to be zero for the dot products.
#
# #### **Step 2:**
# * Write a for-loop to compute the dot product of $A$ and $B$ and $B$ and $A$,and by multiple the products of corredponding elements of $A$ and $B$ and added to the initialized variable, respectively
# * Manually compute the dot products to verify the results from your code.
#
# #### **Step 3:** print the results of dot products of $A$ and $B$ and $B$ and $A$, and the difference of the two dot products. (Make sure that you add some identifications for each print statement)
#
# #### **Step 4:** Add a for loop to repeat 10 times the Python code in **Step 1 - Step 3** (Ignore the manual verification).  The for-loop should include a counter for the numbers of times the difference between the two dot products are **NOT zero.  If the difference is not zero, print the difference.**
#
# #### **Step 5:** print out the number of nonezero differences
#
# #### **Step 6:** In a text cell, write your conclusion about the commutative of dot product based on your emperical results and observation of computer precisions.

# %%
import numpy as np

a = np.random.randint(1, 10, 2)
b = np.random.randint(1, 10, 2)
print(a)
print(b)
print()

# compute a^T * b and b^T * a, and test for equality
dp_ab = 0
dp_ba = 0

for i in range(2):
   dp_ab += a[i] * b[i] 
   dp_ba += b[i] * a[i]
print(dp_ab, dp_ba, dp_ab - dp_ba)
print()

nu_zero = 0

# Step 4 - 5
for j in range(10):
   a = np.random.randint(1, 10, 2)
   b = np.random.randint(1, 10, 2)
   print(a)
   print(b)
   print()
# compute a^T * b and b^T * a, and test for equality
   dp_ab = 0
   dp_ba = 0

   for i in range(2):
        dp_ab += a[i] * b[i] 
        dp_ba += b[i] * a[i]
   print(dp_ab, dp_ba, dp_ab - dp_ba)
   print()
   if (dif_dp != 0):
      print(dif_dp)
      nu_zero += 1
print(f"Number of None zero difference is {nu_zero}.")
# Out:
# [6 8]
# [8 3]
#
# 72 72 0
#
# [1 7]
# [4 6]
#
# 46 46 0
#
# [4 5]
# [1 4]
#
# 24 24 0
#
# [2 2]
# [2 4]
#
# 12 12 0
#
# [4 7]
# [8 5]
#
# 67 67 0
#
# [5 4]
# [9 2]
#
# 53 53 0
#
# [6 4]
# [5 4]
#
# 46 46 0
#
# [8 2]
# [8 1]
#
# 66 66 0
#
# [2 1]
# [7 6]
#
# 20 20 0
#
# [2 3]
# [3 9]
#
# 33 33 0
#
# [3 2]
# [4 7]
#
# 26 26 0
#
# Number of None zero difference is 0.

# %% [markdown]
# ---
# ### **$\color{brown}{\textbf{TODO 3: }}$ Code your experiment with real numbers in $R^n,$**
#
# #### **Step 1:** Generate two 1000-elements random real number row vectors $A$ and $B$ `numpy.random.randn(size)`
# #### **Step 2:** Using Python `numpy.dot(a, b)` to calculate dot products $A^T \cdot B$ and $A^T \cdot B$. Print out $A^T \cdot B$, $A^T \cdot B$, and $A^T \cdot B - A^T \cdot B$ to verify your code.
#
# #### **Step 3:** Test your code with two 2-element integer vectors of your choices.
#
# #### **Step 4:** Add a for loop to repeat 10,000 times the Python code of **Step 1** and **Step 2** (ignore print line).  The for-loop should include a counter for the numbers of times the difference between the two dot products are **NOT zero.  If the difference is not zero, print the different**
#
# #### **Step 5:** print out the number of nonezero differences
#
# #### **Step 6:** In a text cell, write your conclusion about the commutative of dot product based on your emperical results and observation of computer precisions.

# %%
import numpy as np
# Generate two 1000 element vectors

a = np.random.rand(1000)
b = np.random.rand(1000)

# compute a^T * b and b^T * a, and test for equality
dp_ab = np.dot(a, b)
dp_ba = np.dot(b, a)
print(dp_ab, dp_ba, dp_ab - dp_ba)
print()

# test with 2-element random vectors
v = [2, 4]
w = [3, 5]
print(np.dot(v, w),np.dot(w,v), np.dot(v, w) - np.dot(w,v))

nu_zero = 0

for i in range(10000):
    a = np.random.rand(1000)
    b = np.random.rand(1000)

# compute a^T * b and b^T * a, and test for equality
    dp_ab = np.dot(a, b)
    dp_ba = np.dot(b, a)
    dif_dp = dp_ab - dp_ba
    if (dif_dp != 0):
        print(dif_dp)
        nu_zero += 1
print(f"Number of None zero difference is {nu_zero}.")
# Out:
# 248.7828629389371 248.7828629389371 0.0
#
# 26 26 0
# Number of None zero difference is 0.

# %% [markdown]
# ---
# ### **$\color{brown}{\textbf{TODO 4: }}$ Run the experiments**
#
# #### Conduct the experiment by using your code above and documents the results

# %% [markdown]
# ---
# ### **$\color{brown}{\textbf{TODO 5: }}$ Write a discussion and conlusion of your hypothesis**
