# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# # **$$ ⛳ \textbf{ Vector-Vector Multiplication }⛳ $$**
# ## **$$\color{purple}{\textbf{ The Dot or Inner Product}}$$**

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **Objectives**
#
# By the end of this lesson, you will:
#
# #### - Know the various notations to represent the dot product
# #### - Compute the ot product algebraically

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **$\color{blue}{\textbf{Practice: }}$ Notations for and definition of a dot product *(a.k.a)* scalar product or inner product**

# %% [markdown]
# $$
# \Large
# α = \mathbf{a ⋅ b} \,
# =\, \langle \mathbf{a, b} \rangle \,
# =\, \mathbf{a}^\text{T}\mathbf{b} \,
# =\, \sum_i^n \mathbf{a}_i \mathbf{b}_i
# $$

# %% [markdown]
# ---
# ### **Example 1 of dot product**

# %% [markdown]
# ###$$\LARGE
#   \stackrel{\stackrel{\LARGE \color{blue}{\textbf{v}}}{\mbox{   }}}{%
#     \color{blue}{\begin{bmatrix}
#     1 \\
#     0 \\
#     2 \\
#     5\\
#     -2
#     \end{bmatrix}}%
#   }\ \quad
#   \stackrel{\stackrel{\LARGE \color{magenta}{\textbf{w}}}{\mbox{   }}}{%
#     \color{magenta}{\begin{bmatrix}
#     2 \\
#     8 \\
#     -6 \\
#     1\\
#     0
#     \end{bmatrix}}%
#   }\ \quad
# \begin{align}
# \hspace{15mm} \color{blue}{\textbf{v}}^{\text{T}}\color{magenta}{\textbf{w}}\,&=\, \color{blue}{1}\cdot\color{magenta}{2}\, +\, \color{blue}{0}\cdot\color{magenta}{8}\, +\, \color{blue}{2}\cdot(\color{magenta}{-6})\, +\, \color{blue}{5}\cdot\color{magenta}{1}\, +\, (\color{blue}{-2})\cdot\color{magenta}{0}\\
# &=2-12+5\\
# &=-5
# \end{align}
# $$

# %% [markdown]
# ---
# ### **Example 2 of dot product**

# %% [markdown]
# ###$$\LARGE
#   \stackrel{\stackrel{\LARGE \color{blue}{\textbf{v}}}{\mbox{   }}}{%
#     \color{blue}{\begin{bmatrix}
#     1 \\
#     0 \\
#     2 \\
#     5\\
#     -2
#     \end{bmatrix}}%
#   }\ \quad
#   \stackrel{\stackrel{\LARGE \color{magenta}{\textbf{w}}}{\mbox{   }}}{%
#     \color{magenta}{\begin{bmatrix}
#     2 \\
#     8 \\
#     -6 \\
#     \end{bmatrix}}%
#   }\ \quad
# \hspace{15mm} \color{blue}{\textbf{v}}^{\text{T}}\color{magenta}{\textbf{w}}\,=\, \color{blue}{1}\cdot\color{magenta}{2}\, +\, \color{blue}{0}\cdot\color{magenta}{8}\, +\, \color{blue}{2}\cdot(\color{magenta}{-6})\, +\, \color{blue}{5}\cdot\color{magenta}{?}\, +\, (\color{blue}{-2})\cdot\color{magenta}{?}
# $$

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **Numerical Computation of Dot product with Python**

# %% [markdown]
# $$\LARGE\alpha \,= \,\mathbf{a\cdot b} \,= \,\langle \mathbf{a},  \mathbf{b}\rangle\, =\, \mathbf{a}^{\text{T}}\mathbf{b} \,= \,\sum_i^n\mathbf{a}_i\mathbf{b}_i$$

# %% [markdown]
# ###$$\LARGE
#   \stackrel{\stackrel{\LARGE \color{blue}{\textbf{v1}}}{\mbox{   }}}{%
#     \color{blue}{\begin{bmatrix}
#     6 \\
#     5 \\
#     4 \\
#     3\\
#     2\\
#     1
#     \end{bmatrix}}%
#   }\ \quad
#   \stackrel{\stackrel{\LARGE \color{magenta}{\textbf{v2}}}{\mbox{   }}}{%
#     \color{magenta}{\begin{bmatrix}
#     0 \\
#     6 \\
#     -3 \\
#      2 \\
#     -1 \\
#     7\\
#     \end{bmatrix}}%
#    } $$

# %% [markdown]
# ---
# ### **🔖 $\color{blue}{\textbf{Practice: }}$ Method 1: Using native Python** code to translate the mathematical definition of a dot product of vectors **v1** and **v2**. $$\LARGE\sum_i^n\mathbf{v1}_i\cdot \mathbf{v2}_i$$

# %%
# create 2 vectors as list
v1 = [6, 5, 4, 2, 1]
v2 = [0, 6, 4, 6, 5]

# verify if a dot product is valid
if (len(v1) != len(v2)):
    print(f"the dimensionality of the 2 vectors {len(v1)} and {len(v2)} do not match. So no dot product.")
else:
    # intialize a variable to stoe the dot product as a sum
    dot_product = 0
    for i in range(len(v1)): # loop through the length of the vectors
        # this indentation is for the for loop
        dot_product += v1[i] * v2[i] # can never skip a multiplication in any programming language

print(f"If v1 = {v1} and v2 = {v2}")
print(f"Their dot product = {dot_product}")
# Out:
# If v1 = [6, 5, 4, 2, 1] and v2 = [0, 6, 4, 6, 5]
# Their dot product = 63

# %% [markdown]
# ---
# ### **🔖 $\color{blue}{\textbf{Practice: }}$ Method 2: [`numpy.multiply()`](https://numpy.org/doc/stable/reference/generated/numpy.multiply.html)** code to translate the mathematical definition of a dot product of vectors **v1** and **v2**.
# $$\LARGE\sum_i^n\mathbf{v1}_i\cdot \mathbf{v2}_i$$

# %%
import numpy as np

# create 2 vectors as list
v1 = [6, 5, 4, 2, 1]
v2 = [0, 6, 4, 6, 5]

# verify if a dot product is valid
if (len(v1) != len(v2)):
    print(f"the dimensionality of the 2 vectors {len(v1)} and {len(v2)} do not match. So no dot product.")
else:
    # intialize a variable to stoe the dot product as a sum
    dot_product = 0
    for i in range(len(v1)): # loop through the length of the vectors
        # this indentation is for the for loop
        # dot_product += v1[i] * v2[i] # can never skip a multiplication in any programming language
        dot_product += np.multiply(v1[i], v2[i])


print(f"If v1 = {v1} and v2 = {v2}")
print(f"Their dot product = {dot_product}")
# Out:
# If v1 = [6, 5, 4, 2, 1] and v2 = [0, 6, 4, 6, 5]
# Their dot product = 63

# %% [markdown]
# ---
# ### **🔖 $\color{blue}{\textbf{Practice: }}$ Method 3: Using `numpy` library [`numpy.multiply()`](https://numpy.org/doc/stable/reference/generated/numpy.matmul.html)** code to translate the mathematical definition of a dot product of vectors **v1** and **v2**.
# $$\LARGE\mathbf{a\cdot b} \,= \,\langle \mathbf{a},  \mathbf{b}\rangle\, =\, \mathbf{a}^{\text{T}}\mathbf{b} $$

# %%
import numpy as np

# create 2 vectors as list
v1 = [6, 5, 4, 2, 1]
v2 = [0, 6, 4, 6, 5]

# verify if a dot product is valid
if (len(v1) != len(v2)):
    print(f"the dimensionality of the 2 vectors {len(v1)} and {len(v2)} do not match. So no dot product.")
else:
    # intialize a variable to stoe the dot product as a sum
    dot_product = sum(np.multiply(v1, v2))


print(f"If v1 = {v1} and v2 = {v2}")
print(f"Their dot product = {dot_product}")
# Out:
# If v1 = [6, 5, 4, 2, 1] and v2 = [0, 6, 4, 6, 5]
# Their dot product = 63

# %% [markdown]
# ---
# ### **🔖 $\color{blue}{\textbf{Practice: }}$ Method 4: Using `numpy` library [`numpy.dot()`](https://numpy.org/doc/stable/reference/generated/numpy.dot.html)** code to translate the mathematical definition of a dot product of vectors **v1** and **v2**.
# $$\LARGE\mathbf{a\cdot b} \,= \,\langle \mathbf{a},  \mathbf{b}\rangle\, =\, \mathbf{a}^{\text{T}}\mathbf{b} $$

# %%
import numpy as np

# create 2 vectors as list
v1 = [6, 5, 4, 2, 1]
v2 = [0, 6, 4, 6, 5]

# verify if a dot product is valid
if (len(v1) != len(v2)):
    print(f"the dimensionality of the 2 vectors {len(v1)} and {len(v2)} do not match. So no dot product.")
else:
    # intialize a variable to stoe the dot product as a sum
    dot_product = np.dot(v1, v2)
    # dot_product = np.matmul(v1, v2)


print(f"If v1 = {v1} and v2 = {v2}")
print(f"Their dot product = {dot_product}")
# Out:
# If v1 = [6, 5, 4, 2, 1] and v2 = [0, 6, 4, 6, 5]
# Their dot product = 63

# %% [markdown]
# ---
# ### **🔖 $\color{blue}{\textbf{Practice: }}$ Method 4: Using `numpy` library [`numpy.matmul()`](https://numpy.org/doc/stable/reference/generated/numpy.matmul.html)** code to translate the mathematical definition of a dot product of vectors **v1** and **v2**.

# %%
import numpy as np

# create 2 vectors as list
v1 = [6, 5, 4, 2, 1]
v2 = [0, 6, 4, 6, 5]

# verify if a dot product is valid
if (len(v1) != len(v2)):
    print(f"the dimensionality of the 2 vectors {len(v1)} and {len(v2)} do not match. So no dot product.")
else:
    # intialize a variable to stoe the dot product as a sum
    # dot_product = np.dot(v1, v2)
    dot_product = np.matmul(v1, v2)


print(f"If v1 = {v1} and v2 = {v2}")
print(f"Their dot product = {dot_product}")
# Out:
# If v1 = [6, 5, 4, 2, 1] and v2 = [0, 6, 4, 6, 5]
# Their dot product = 63
