# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# # **$$ ⛳ \textbf{ Dot product Properties: }⛳ $$**

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **Objectives**
#
# By the end of this lesson, you will:
#
# #### - Learn two important properties of dot products
# #### - See if the dot product has the distributive, associative, and commutative propoerties.

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **Is the dot product distributive**
#
#
# <details>
#
# <summary><b>Formal Mathematical definition </b></summary>
#
# **Definition of distributive of multiplication over additions by Wiki**
#
# Given a set $S$ and two binary operation * and $+$ on $S$,
# * the operation * is *left-distributive over * (or with respect to) $+$ if, given elements $x, y, $ and $z$ of $S$,
# $$x * (y+z) = (x*y) + (x*z);$$
# * the operation * is *right-distributive* over $+$ if, given any elements $x, y$, and $z$ of $S$,
# $$(y+z)*z=(y*x)+(z*x);$$
# * and the operation * is *distributive* over $+$ if it is left- and right-distributive.
#
# When * is commutative, the three conditions above are logically equivalent.
#
# </details>

# %% [markdown]
# ### **Distributive of dot product**
#
# ####Given three column vectors with the same dimentionality $n$, then
# #### $$\Large \mathbf{a}^\text{T}\mathbf{(b+c)} \,\stackrel{?}{=} \, \mathbf{a}^{\text{T}}\mathbf{b} \, +\, \mathbf{a}^{\text{T}}\mathbf{c}  $$
#
# #### or in components
#
# $$\Large  \,\sum_i^n\mathbf{a}_i \left (\mathbf{b}_i+ \mathbf{c}_i \right ) \stackrel{?}{=} \,\sum_i^n\mathbf{a}_i\mathbf{b}_i + \,\sum_i^n\mathbf{a}_i\mathbf{c}_i$$

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **Is dot product associative?**
#
#
# <details>
#
# <summary><b>Formal Mathematical definition </b></summary>
#
# **Definition of distributive of multiplication over additions by [Wiki](https://en.wikipedia.org/wiki/Associative_property)**
#
# Finally, a binary operation * on a set $S$ is called **associative** if it satisfies the **associative law**:
#
# $$(x * y) * z = z * ( y * z) $$ for all $x, y, z$, in $S$
#
# </details>

# %% [markdown]
# ###Given three column vectors $\mathbf{a}$, $\mathbf{b}$ and $\mathbf{c}$ with the same dimentionality $n$, then
# #### $$
# \LARGE
# \mathbf{a}^\text{T}\underbrace{\mathbf{(b}^\text{T}\mathbf{c)} }_{\color{green}{\textbf{Scalar}}}
# \,
# \stackrel{?}{\color{red}{\ne}}
# \,
# \underbrace{(\mathbf{a}^{\text{T}}\mathbf{b}}_{\color{green}{\textbf{Scalar}}} )^\text{T}\mathbf{c}
# $$

# %% [markdown]
# ---
# ### **Is the dot product is associative in the special Cases (Edge Cases)**
#
# ### **Case 1: one of the vectors $\mathbf{a, b}$, or $\mathbf{c}$ is the zero vector.**
#
# ### **Case 2: $\mathbf{a = b = c}$**
#
# $$\LARGE\mathbf{a}^\text{T}\mathbf{(b}^\text{T}\mathbf{c)}\,\stackrel{?}{\color{red}{=}}  \,  (\mathbf{a}^{\text{T}}\mathbf{b} )^\text{T}\mathbf{c}$$

# %% [markdown]
# ---
#
# ### 🟨 **NOTE:**
#
# You shouldn't think that somehow the associative property is never valid in **linear algebra**.
#
# In fact, this associative property for matrix multiplications turns out to be really crucial for quite a few proofs in advanced linear algebra.
#
# $$\Large\mathbf{A(BC) \stackrel{?}{\color{red}{=}}  (AB)C}$$
#
# where $\mathbf{A, B}$ and $ \mathbf{C}$ are matrices.

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## **Is the dot product commutative**
#
#
# <details>
#
# <summary><b>Formal Mathematical definition </b></summary>
#
# **Definition of distributive of multiplication over additions by [Wiki](https://en.wikipedia.org/wiki/Commutative_property)**
#
# Finally, a binary operation * on a set $S$ is called **commutative** if :
#
# $$x * y = y * x $$ for all $x, y$, in $S$
#
# An operation that does not satisfy the above property is called non-commutative.
#
# </details>

# %% [markdown]
# ### $$\Large \mathbf{A}^\text{T} \cdot \mathbf{B} \stackrel{?}{=} \mathbf{B}^\text{T}\cdot \mathbf{A}$$

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# ## **Demo of Homework with Code**
#
# > ### **[HW-w-Code](https://colab.research.google.com/drive/1G5mkl5NcSV-MkUy5Woa73qB7dB9wBq2P?usp=share_link) 1.6 Is dot product distributuve?**
# > ### **[LAB](https://colab.research.google.com/drive/10gCUWepK8xL58lJ_6oba-7kzYnOAKzjh?usp=share_link) 1.7 Is dot product associative?**
